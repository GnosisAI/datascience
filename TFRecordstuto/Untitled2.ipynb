# %%
from PIL import Image
import numpy as np

# %%
path = './datasets/chest_xray/train/NORMAL'

# %%
image_path = path+'/NORMAL2-IM-0478-0001.jpeg'

# %%
image = Image.open(image_path)

# %%
image = image.resize((500,500))

# %%
img = np.array(image)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img/255)

# %%
from skimage.color import rgb2gray

# %%
np.array(image).shape
# Out:
# (1638, 1724)

# %%
byt = img.tostring()

# %%
byt == img.tobytes()
# Out:
# True

# %%
np.frombuffer(byt).shape
# Out:
# (31250,)
